# %% [markdown]
# ## Task 3: Global Temperature Changes for 1pctCO2

# %% [markdown]
# Goal is to preprocess the global temperature data for 1pctCO2. This model shows the scenario of which CO2 concentration increases by 1% each year. In this process, we don't have to look at any models except for 1pctCO2.

# %%
#imports
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
import xarray as xr
import zarr
import gcsfs
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
df.head()
# Out:
#   activity_id institution_id     source_id       experiment_id member_id  \
# 0  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 1  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 2  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 3  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
# 4  HighResMIP           CMCC  CMCC-CM2-HR4  highresSST-present  r1i1p1f1
#
#   table_id variable_id grid_label  \
# 0     Amon          ps         gn
# 1     Amon        rsds         gn
# 2     Amon        rlus         gn
# 3     Amon        rlds         gn
# 4     Amon         psl         gn
#
#                                               zstore  dcpp_init_year   version
# 0  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 1  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 2  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 3  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706
# 4  gs://cmip6/CMIP6/HighResMIP/CMCC/CMCC-CM2-HR4/...             NaN  20170706

# %%
def load_zarr_dset(df):
  # get the path to a specific zarr store (the first one from the dataframe above)
  zstore = df.zstore.values[-1]

  # create a mutable-mapping-style interface to the store
  mapper = gcs.get_mapper(zstore)

  # open it using xarray and zarr
  ds = xr.open_zarr(mapper, consolidated=True)
  return ds

# %%
gcs = gcsfs.GCSFileSystem(token='anon')

# %%
#time index to assign model times to
new_time_index=pd.date_range('1850-01-01', '2099-12-31', freq='ME')
new_time_index
# Out:
# DatetimeIndex(['1850-01-31', '1850-02-28', '1850-03-31', '1850-04-30',
#                '1850-05-31', '1850-06-30', '1850-07-31', '1850-08-31',
#                '1850-09-30', '1850-10-31',
#                ...
#                '2099-03-31', '2099-04-30', '2099-05-31', '2099-06-30',
#                '2099-07-31', '2099-08-31', '2099-09-30', '2099-10-31',
#                '2099-11-30', '2099-12-31'],
#               dtype='datetime64[ns]', length=3000, freq='ME')

# %%
df['experiment_id'].unique()
# Out:
# array(['highresSST-present', 'piControl', 'control-1950', 'hist-1950',
#        'historical', 'amip', 'abrupt-4xCO2', 'abrupt-2xCO2',
#        'abrupt-0p5xCO2', '1pctCO2', 'ssp585', 'esm-piControl', 'esm-hist',
#        'hist-piAer', 'histSST-1950HC', 'ssp245', 'hist-1950HC', 'histSST',
#        'piClim-2xVOC', 'piClim-2xNOx', 'piClim-2xdust', 'piClim-2xss',
#        'piClim-histall', 'hist-piNTCF', 'histSST-piNTCF',
#        'aqua-control-lwoff', 'piClim-lu', 'histSST-piO3', 'piClim-CH4',
#        'piClim-NTCF', 'piClim-NOx', 'piClim-O3', 'piClim-HC',
#        'faf-heat-NA0pct', 'ssp370SST-lowCH4', 'piClim-VOC',
#        'ssp370-lowNTCF', 'piClim-control', 'piClim-aer', 'hist-aer',
#        'faf-heat', 'faf-heat-NA50pct', 'ssp370SST-lowNTCF',
#        'ssp370SST-ssp126Lu', 'ssp370SST', 'ssp370pdSST', 'histSST-piAer',
#        'piClim-ghg', 'piClim-anthro', 'faf-all', 'hist-nat', 'hist-GHG',
#        'ssp119', 'piClim-histnat', 'piClim-4xCO2', 'ssp370',
#        'piClim-histghg', 'highresSST-future', 'esm-ssp585-ssp126Lu',
#        'ssp126-ssp370Lu', 'ssp370-ssp126Lu', 'land-noLu', 'histSST-piCH4',
#        'ssp126', 'esm-pi-CO2pulse', 'amip-hist', 'piClim-histaer',
#        'amip-4xCO2', 'faf-water', 'faf-passiveheat', '1pctCO2-rad',
#        'faf-stress', '1pctCO2-bgc', 'aqua-control', 'amip-future4K',
#        'amip-p4K', 'aqua-p4K', 'amip-lwoff', 'amip-m4K', 'aqua-4xCO2',
#        'amip-p4K-lwoff', 'hist-noLu', '1pctCO2-cdr',
#        'land-hist-altStartYear', 'land-hist', 'omip1', 'esm-pi-cdr-pulse',
#        'esm-ssp585', 'abrupt-solp4p', 'piControl-spinup', 'hist-stratO3',
#        'abrupt-solm4p', 'midHolocene', 'lig127k', 'aqua-p4K-lwoff',
#        'esm-piControl-spinup', 'ssp245-GHG', 'ssp245-nat',
#        'dcppC-amv-neg', 'dcppC-amv-ExTrop-neg', 'dcppC-atl-control',
#        'dcppC-amv-pos', 'dcppC-ipv-NexTrop-neg', 'dcppC-ipv-NexTrop-pos',
#        'dcppC-atl-pacemaker', 'dcppC-amv-ExTrop-pos',
#        'dcppC-amv-Trop-neg', 'dcppC-pac-control', 'dcppC-ipv-pos',
#        'dcppC-pac-pacemaker', 'dcppC-ipv-neg', 'dcppC-amv-Trop-pos',
#        'piClim-BC', 'piClim-2xfire', 'piClim-SO2', 'piClim-OC',
#        'piClim-N2O', 'piClim-2xDMS', 'ssp460', 'ssp434', 'ssp534-over',
#        'deforest-globe', 'historical-cmip5', 'hist-bgc',
#        'piControl-cmip5', 'rcp26-cmip5', 'rcp45-cmip5', 'rcp85-cmip5',
#        'pdSST-piArcSIC', 'pdSST-piAntSIC', 'piSST-piSIC', 'piSST-pdSIC',
#        'ssp245-stratO3', 'hist-sol', 'hist-CO2', 'hist-volc',
#        'hist-totalO3', 'hist-nat-cmip5', 'hist-aer-cmip5',
#        'hist-GHG-cmip5', 'pdSST-futAntSIC', 'futSST-pdSIC', 'pdSST-pdSIC',
#        'ssp245-aer', 'pdSST-futArcSIC', 'dcppA-hindcast', 'dcppA-assim',
#        'dcppC-hindcast-noPinatubo', 'dcppC-hindcast-noElChichon',
#        'dcppC-hindcast-noAgung', 'hist-resIPO', 'ssp245-cov-modgreen',
#        'ssp245-cov-fossil', 'ssp245-cov-strgreen', 'ssp245-covid', 'lgm',
#        'ssp585-bgc', '1pctCO2to4x-withism', '1pctCO2-4xext', 'past1000',
#        'pa-futArcSIC', 'pa-pdSIC', 'historical-ext', 'pdSST-futArcSICSIT',
#        'pdSST-futOkhotskSIC', 'pdSST-futBKSeasSIC', 'pa-piArcSIC',
#        'pa-piAntSIC', 'pa-futAntSIC', 'pdSST-pdSICSIT'], dtype=object)

# %%
#query tas models that are for 1pctCO2
df_tas_1pctCO2 = df.query ("activity_id == 'CMIP' & table_id == 'Amon' & variable_id == 'tas' & experiment_id == '1pctCO2'")
models_tas_1pctCO2 = set(df_tas_1pctCO2['source_id'])
source_list = list(models_tas_1pctCO2)
print(len(source_list))
# Out:
# 59

# %%
source_list
# Out:
# ['FGOALS-g3',
#  'FIO-ESM-2-0',
#  'UKESM1-0-LL',
#  'GFDL-CM4',
#  'NorESM2-MM',
#  'KIOST-ESM',
#  'CNRM-ESM2-1',
#  'BCC-CSM2-MR',
#  'FGOALS-f3-L',
#  'EC-Earth3-CC',
#  'SAM0-UNICON',
#  'MPI-ESM-1-2-HAM',
#  'CESM2',
#  'HadGEM3-GC31-LL',
#  'CMCC-CM2-HR4',
#  'CMCC-ESM2',
#  'CAS-ESM2-0',
#  'CESM2-WACCM-FV2',
#  'CNRM-CM6-1',
#  'MIROC6',
#  'MRI-ESM2-0',
#  'MPI-ESM1-2-HR',
#  'NorESM2-LM',
#  'MIROC-ES2L',
#  'GISS-E2-2-H',
#  'NESM3',
#  'E3SM-1-0',
#  'KACE-1-0-G',
#  'ICON-ESM-LR',
#  'EC-Earth3-AerChem',
#  'IPSL-CM5A2-INCA',
#  'BCC-ESM1',
#  'AWI-CM-1-1-MR',
#  'CNRM-CM6-1-HR',
#  'CESM2-FV2',
#  'EC-Earth3',
#  'MPI-ESM1-2-LR',
#  'INM-CM4-8',
#  'NorCPM1',
#  'EC-Earth3-Veg',
#  'GISS-E2-1-H',
#  'GISS-E2-1-G',
#  'CMCC-CM2-SR5',
#  'CESM2-WACCM',
#  'GISS-E2-2-G',
#  'ACCESS-CM2',
#  'HadGEM3-GC31-MM',
#  'AWI-ESM-1-1-LR',
#  'INM-CM5-0',
#  'GFDL-ESM4',
#  'CAMS-CSM1-0',
#  'TaiESM1',
#  'IPSL-CM6A-LR',
#  'ACCESS-ESM1-5',
#  'MCM-UA-1-0',
#  'CanESM5',
#  'CIESM',
#  'CanESM5-CanOE',
#  'IITM-ESM']

# %%
#we can do a similar process where we look at r1f1i1pi first and then fill in the gaps for the rest of the models

# %%
df_tas_1pctCO2 = df.query ("activity_id == 'CMIP' & table_id == 'Amon' & variable_id == 'tas' & experiment_id == '1pctCO2' & member_id == 'r1i1p1f1'")
models_tas_1pctCO2 = set(df_tas_1pctCO2['source_id'])
source_list = list(models_tas_1pctCO2)
print(len(source_list))
# Out:
# 50

# %%
source_list
# Out:
# ['FGOALS-g3',
#  'FIO-ESM-2-0',
#  'NorESM2-MM',
#  'GFDL-CM4',
#  'KIOST-ESM',
#  'BCC-CSM2-MR',
#  'FGOALS-f3-L',
#  'EC-Earth3-CC',
#  'SAM0-UNICON',
#  'MPI-ESM-1-2-HAM',
#  'CESM2',
#  'CMCC-CM2-HR4',
#  'CMCC-ESM2',
#  'CAS-ESM2-0',
#  'CESM2-WACCM-FV2',
#  'MIROC6',
#  'MRI-ESM2-0',
#  'MPI-ESM1-2-HR',
#  'NorESM2-LM',
#  'GISS-E2-2-H',
#  'NESM3',
#  'E3SM-1-0',
#  'KACE-1-0-G',
#  'ICON-ESM-LR',
#  'EC-Earth3-AerChem',
#  'IPSL-CM5A2-INCA',
#  'BCC-ESM1',
#  'AWI-CM-1-1-MR',
#  'CESM2-FV2',
#  'MPI-ESM1-2-LR',
#  'INM-CM4-8',
#  'NorCPM1',
#  'EC-Earth3-Veg',
#  'GISS-E2-1-H',
#  'CMCC-CM2-SR5',
#  'CESM2-WACCM',
#  'GISS-E2-2-G',
#  'ACCESS-CM2',
#  'AWI-ESM-1-1-LR',
#  'INM-CM5-0',
#  'GFDL-ESM4',
#  'CAMS-CSM1-0',
#  'TaiESM1',
#  'IPSL-CM6A-LR',
#  'ACCESS-ESM1-5',
#  'MCM-UA-1-0',
#  'CanESM5',
#  'CIESM',
#  'GISS-E2-1-G',
#  'IITM-ESM']

# %%
#checking to see if the models go from 1850-2000
for source in source_list:
    print("\n"+source)
    print(ds_tas_1pctCO2_fgoalsg3.time[0])
    print(ds_tas_1pctCO2_fgoalsg3.time[-1])
# Out:
# FGOALS-g3
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# FIO-ESM-2-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# NorESM2-MM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# GFDL-CM4
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# KIOST-ESM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# BCC-CSM2-MR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# FGOALS-f3-L
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# EC-Earth3-CC
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# SAM0-UNICON
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# MPI-ESM-1-2-HAM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CESM2
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CMCC-CM2-HR4
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CMCC-ESM2
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CAS-ESM2-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CESM2-WACCM-FV2
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# MIROC6
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# MRI-ESM2-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# MPI-ESM1-2-HR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# NorESM2-LM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# GISS-E2-2-H
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# NESM3
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# E3SM-1-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# KACE-1-0-G
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# ICON-ESM-LR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# EC-Earth3-AerChem
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# IPSL-CM5A2-INCA
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# BCC-ESM1
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# AWI-CM-1-1-MR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CESM2-FV2
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# MPI-ESM1-2-LR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# INM-CM4-8
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# NorCPM1
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# EC-Earth3-Veg
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# GISS-E2-1-H
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CMCC-CM2-SR5
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CESM2-WACCM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# GISS-E2-2-G
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# ACCESS-CM2
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# AWI-ESM-1-1-LR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# INM-CM5-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# GFDL-ESM4
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CAMS-CSM1-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# TaiESM1
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# IPSL-CM6A-LR
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# ACCESS-ESM1-5
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# MCM-UA-1-0
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CanESM5
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# CIESM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# GISS-E2-1-G
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
#
# IITM-ESM
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time

# %% [markdown]
# ### 1.1 Loading One Model

# %%
#access data
df_tas_1pctCO2_fgoalsg3 = df.query("activity_id == 'CMIP' & source_id == 'FGOALS-g3' & table_id == 'Amon' & variable_id == 'tas' & experiment_id == '1pctCO2' & member_id == 'r1i1p1f1'")
ds_tas_1pctCO2_fgoalsg3 = load_zarr_dset(df_tas_1pctCO2)
#load temperature data
tas_1pct_fgoalsg3 = ds_tas_1pctCO2_fgoalsg3.tas
#weights of the area of the grid cells
weight_fgoalsg3 = np.cos(np.deg2rad(tas_1pct_fgoalsg3.lat))
#mean of weighted tas_1_pct_fgoalsg3
ds_tas_1pctCO2_fgoalsg3_w_mean = tas_1pct_fgoalsg3.weighted(weight_fgoalsg3).mean(dim=('lon', 'lat'))
ds_tas_1pctCO2_fgoalsg3_w_mean
# Out:
# <xarray.DataArray 'tas' (time: 1812)>
# dask.array<truediv, shape=(1812,), dtype=float64, chunksize=(677,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 1850-01-17 12:00:00 ... 2000-12-17 12:00:00

# %%
fig, ax = plt.subplots(figsize = (40,6))
ds_tas_1pctCO2_fgoalsg3_w_mean.plot(ax=ax)
plt.title("FGOALS-g3 Global Mean Temperature")
# Out:
# Text(0.5, 1.0, 'FGOALS-g3 Global Mean Temperature')

# %% [markdown]
# ### 1.2 Load Multiple Models

# %%
gcm_list = ['FIO-ESM-2-0',
 'NorESM2-MM',
 'GFDL-CM4',
 'KIOST-ESM',
 'BCC-CSM2-MR']

# %%
ds_list = list()
for source in gcm_list:
    df_tas_1pctCO2_fgoalsg3 = df.query("activity_id == 'CMIP' & source_id == 'FGOALS-g3' & table_id == 'Amon' & variable_id == 'tas' & experiment_id == '1pctCO2' & member_id == 'r1i1p1f1'")
    ds_tas_1pctCO2_fgoalsg3 = load_zarr_dset(df_tas_1pctCO2)
    #print models time start and end
    print("
    print(ds_tas_1pctCO2_fgoalsg3.time[0])
    print(ds_tas_1pctCO2_fgoalsg3.time[-1])
    #slice first and then assign
    tas_fgoalsg3 = ds_tas_1pctCO2_fgoalsg3.isel(time = slice(0,3000))
    ds_fgoalsg3 = tas_fgoalsg3.assign(time=new_time_index)
    ds_fgoalsg3 = ds_fgoalsg3.assign_coords(model=source)           
    #weights of the area of the grid cells
    weight_fgoalsg3 = np.cos(np.deg2rad(ds_tas_1pctCO2_fgoalsg3.tas.lat))
    #mean of weighted tas_1_pct_fgoalsg3
    ds_all = ds_fgoalsg3.weighted(weight_fgoalsg3).mean(dim=('lon','lat'))

    #add to list
    ds_list.append(ds_all)
ob_all_gcm = xr.concat(ds_list, dim = 'model', coords = 'minimal', compat = 'override')
ob_all_gcm

#i need to make this into a dataarray, but the problem is we dont have to concat dataarrays together
# Out:
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(1850, 1, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 1850-01-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# <xarray.DataArray 'time' ()>
# array(cftime.DatetimeNoLeap(2000, 12, 17, 12, 0, 0, 0, has_year_zero=True),
#       dtype=object)
# Coordinates:
#     time     object 2000-12-17 12:00:00
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 10
#       8 #slice first and then assign
#       9 tas_fgoalsg3 = ds_tas_1pctCO2_fgoalsg3.isel(time = slice(0,3000))
# ---> 10 ds_fgoalsg3 = tas_fgoalsg3.assign(time=new_time_index)
#      11 ds_fgoalsg3 = ds_fgoalsg3.assign_coords(model=source)
#      12 #weights of the area of the grid cells
#
# File ~\miniconda3\envs\temp_var\Lib\site-packages\xarray\core\dataset.py:6160, in Dataset.assign(self, variables, **variables_kwargs)
#    6158 data.coords._maybe_drop_multiindex_coords(set(results.keys()))
#    6159 # ... and then assign
# -> 6160 data.update(results)
#    6161 return data
#
# File ~\miniconda3\envs\temp_var\Lib\site-packages\xarray\core\dataset.py:5026, in Dataset.update(self, other)
#    4990 def update(self: T_Dataset, other: CoercibleMapping) -> T_Dataset:
#    4991     """Update this dataset's variables with those from another dataset.
#    4992
#    4993     Just like :py:meth:`dict.update` this is a in-place operation.
#    (...)
#    5024     Dataset.merge
#    5025     """
# -> 5026     merge_result = dataset_update_method(self, other)
#    5027     return self._replace(inplace=True, **merge_result._asdict())
#
# File ~\miniconda3\envs\temp_var\Lib\site-packages\xarray\core\merge.py:1104, in dataset_update_method(dataset, other)
#    1101             if coord_names:
#    1102                 other[key] = value.drop_vars(coord_names)
# -> 1104 return merge_core(
#    1105     [dataset, other],
#    1106     priority_arg=1,
#    1107     indexes=dataset.xindexes,
#    1108     combine_attrs="override",
#    1109 )
#
# File ~\miniconda3\envs\temp_var\Lib\site-packages\xarray\core\merge.py:761, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value)
#     756 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
#     757 variables, out_indexes = merge_collected(
#     758     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     759 )
# --> 761 dims = calculate_dimensions(variables)
#     763 coord_names, noncoord_names = determine_coords(coerced)
#     764 if explicit_coords is not None:
#
# File ~\miniconda3\envs\temp_var\Lib\site-packages\xarray\core\variable.py:3282, in calculate_dimensions(variables)
#    3280             last_used[dim] = k
#    3281         elif dims[dim] != size:
# -> 3282             raise ValueError(
#    3283                 f"conflicting sizes for dimension {dim!r}: "
#    3284                 f"length {size} on {k!r} and length {dims[dim]} on {last_used!r}"
#    3285             )
#    3286 return dims
#
# ValueError: conflicting sizes for dimension 'time': length 3000 on 'time' and length 1812 on {'lat': 'lat', 'bnds': 'lat_bnds', 'lon': 'lon', 'time': 'tas'}
